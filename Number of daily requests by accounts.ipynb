# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
# Import daily_requests.csv file from database
df = pd.read_csv('/Users/zack/Documents/GIA HOANG/HOSS/daily_requests.csv')
df
# Out:
#      account_id                          account_uuid  account_name  \
# 0             2  d293c950-5e16-4e60-ac50-36b21a395f2b          Hoss
# 1             2  d293c950-5e16-4e60-ac50-36b21a395f2b          Hoss
# 2             2  d293c950-5e16-4e60-ac50-36b21a395f2b          Hoss
# 3             2  d293c950-5e16-4e60-ac50-36b21a395f2b          Hoss
# 4            15  0b44a4a3-6fa6-4378-98aa-77ef8a497990          João
# ..          ...                                   ...           ...
# 796         343  89ad85e5-f79d-4b38-a7c8-39dee1aef50b    Invoice2Go
# 797         343  89ad85e5-f79d-4b38-a7c8-39dee1aef50b    Invoice2Go
# 798         344  2386bbdb-68a9-490d-a2de-492b467ac63d  Build A Sign
# 799         370  aa02ddd9-7c6f-4f56-8fbe-6ec06b4e7b6a       Wirewax
# 800         370  aa02ddd9-7c6f-4f56-8fbe-6ec06b4e7b6a       Wirewax
#
#     created_at  plan_id  plan_name     date  requests
# 0      5/24/20        2  Hoss Plus  7/14/20        41
# 1      5/24/20        2  Hoss Plus  7/13/20        90
# 2      5/24/20        2  Hoss Plus   7/7/20        65
# 3      5/24/20        2  Hoss Plus  6/11/20        11
# 4      5/28/20        1       Free  6/26/20        33
# ..         ...      ...        ...      ...       ...
# 796    7/21/20        2  Hoss Plus  7/22/20     41574
# 797    7/21/20        2  Hoss Plus  7/21/20      2779
# 798    7/21/20        1       Free  7/22/20      1745
# 799    7/28/20        1       Free  7/30/20      2256
# 800    7/28/20        1       Free  7/29/20      1113
#
# [801 rows x 8 columns]

# %%
# Filter necessary columns
df1= df[['account_id', 'account_name','date','requests']]
df1
# Out:
#      account_id  account_name     date  requests
# 0             2          Hoss  7/14/20        41
# 1             2          Hoss  7/13/20        90
# 2             2          Hoss   7/7/20        65
# 3             2          Hoss  6/11/20        11
# 4            15          João  6/26/20        33
# ..          ...           ...      ...       ...
# 796         343    Invoice2Go  7/22/20     41574
# 797         343    Invoice2Go  7/21/20      2779
# 798         344  Build A Sign  7/22/20      1745
# 799         370       Wirewax  7/30/20      2256
# 800         370       Wirewax  7/29/20      1113
#
# [801 rows x 4 columns]

# %%
# Replace NA values in "account_name" with its "account_id"
df1._update_inplace= df1['account_name'].fillna(df1['account_id'], inplace= True)
df1
# Out:
# /Users/zack/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
#      account_id  account_name     date  requests
# 0             2          Hoss  7/14/20        41
# 1             2          Hoss  7/13/20        90
# 2             2          Hoss   7/7/20        65
# 3             2          Hoss  6/11/20        11
# 4            15          João  6/26/20        33
# ..          ...           ...      ...       ...
# 796         343    Invoice2Go  7/22/20     41574
# 797         343    Invoice2Go  7/21/20      2779
# 798         344  Build A Sign  7/22/20      1745
# 799         370       Wirewax  7/30/20      2256
# 800         370       Wirewax  7/29/20      1113
#
# [801 rows x 4 columns]

# %%
# Pivot the df1 dataframe to get a desired format
daily_request= df1.pivot_table(index=['account_id','account_name'], columns=['date'], values=['requests'])
daily_request
# Out:
#                                                requests                    \
# date                                            6/11/20  6/12/20  6/13/20
# account_id account_name
# 2          Hoss                                    11.0      NaN      NaN
# 15         João                                     NaN      NaN      NaN
# 17         bertelli.dev                             5.0      NaN      NaN
# 18         Linh                                     NaN      NaN      NaN
# 20         Zen Business PBC                      2497.0   2308.0   2200.0
# 22         Hamza Zia                                3.0    111.0      NaN
# 25         Jeremy Evans                         11973.0  11178.0  10669.0
# 26         26                                     121.0      NaN      NaN
# 30         Hoss                                   101.0     23.0      1.0
# 33         Trung                                    NaN      NaN      NaN
# 34         Hoss Test                                NaN      NaN      NaN
# 37         test                                     NaN      NaN      NaN
# 39         Hoss                                     NaN      NaN      NaN
# 40         hoss                                     NaN      NaN      NaN
# 41         zfaeel+10@gmail.com                      NaN      NaN      NaN
# 46         hoss                                     NaN      NaN      NaN
# 59         Lakestar                                 NaN      NaN      NaN
# 79         Carpe Diem                               NaN      NaN      NaN
# 90         Hoss Prod4                               NaN      NaN      NaN
# 104        Abstraction Capital                      NaN      NaN      NaN
# 111        Hive                                     NaN      NaN      NaN
# 112        Gordian Software Inc.                    NaN      NaN      NaN
# 115        YearEnd, Inc.                            NaN      NaN      NaN
# 121        LeoEK                                    NaN      NaN      NaN
# 130        Swishify                                 NaN      NaN      NaN
# 137        Courier                                  NaN      NaN      NaN
# 176        Ripplink                                 NaN      NaN      NaN
# 201        DMC                                      NaN      NaN      NaN
# 215        test                                     NaN      NaN      NaN
# 242        Signzy Technologies Private Limited      NaN      NaN      NaN
# 253        pbp                                      NaN      NaN      NaN
# 256        Self                                     NaN      NaN      NaN
# 270        Blair                                    NaN      NaN      NaN
# 277        Buttondown                               NaN      NaN      NaN
# 291        Hoss                                     NaN      NaN      NaN
# 295        Meadow                                   NaN      NaN      NaN
# 311        beaverlang                               NaN      NaN      NaN
# 320        ZIGGURAT INTERNATIONAL                   NaN      NaN      NaN
# 323        Grain Technology                         NaN      NaN      NaN
# 329        BlueReceipt                              NaN      NaN      NaN
# 341        One Two Smile                            NaN      NaN      NaN
# 343        Invoice2Go                               NaN      NaN      NaN
# 344        Build A Sign                             NaN      NaN      NaN
# 370        Wirewax                                  NaN      NaN      NaN
#
#                                                                            \
# date                                           6/14/20  6/15/20   6/16/20
# account_id account_name
# 2          Hoss                                    NaN      NaN       NaN
# 15         João                                    NaN      NaN       NaN
# 17         bertelli.dev                            NaN      NaN       NaN
# 18         Linh                                    NaN      NaN       NaN
# 20         Zen Business PBC                     2071.0   2679.0    5037.0
# 22         Hamza Zia                               NaN   8804.0   16465.0
# 25         Jeremy Evans                         9862.0  11797.0   19965.0
# 26         26                                      NaN      NaN       NaN
# 30         Hoss                                 2924.0  13364.0   15012.0
# 33         Trung                                   5.0      NaN       NaN
# 34         Hoss Test                               1.0      NaN       NaN
# 37         test                                    1.0      NaN       NaN
# 39         Hoss                                    1.0      NaN       NaN
# 40         hoss                                    1.0      NaN       NaN
# 41         zfaeel+10@gmail.com                     1.0      NaN       NaN
# 46         hoss                                    2.0     15.0       NaN
# 59         Lakestar                                NaN      NaN      14.0
# 79         Carpe Diem                              NaN     94.0       NaN
# 90         Hoss Prod4                              NaN      NaN       NaN
# 104        Abstraction Capital                     NaN     41.0       NaN
# 111        Hive                                    NaN   2217.0       NaN
# 112        Gordian Software Inc.                   NaN      NaN       7.0
# 115        YearEnd, Inc.                           NaN    127.0       NaN
# 121        LeoEK                                   NaN     29.0       NaN
# 130        Swishify                                NaN      NaN     265.0
# 137        Courier                                 NaN      NaN       NaN
# 176        Ripplink                                NaN      NaN  189280.0
# 201        DMC                                     NaN      NaN      93.0
# 215        test                                    NaN      NaN    9000.0
# 242        Signzy Technologies Private Limited     NaN      NaN       NaN
# 253        pbp                                     NaN      NaN       NaN
# 256        Self                                    NaN      NaN       NaN
# 270        Blair                                   NaN      NaN       NaN
# 277        Buttondown                              NaN      NaN       NaN
# 291        Hoss                                    NaN      NaN       NaN
# 295        Meadow                                  NaN      NaN       NaN
# 311        beaverlang                              NaN      NaN       NaN
# 320        ZIGGURAT INTERNATIONAL                  NaN      NaN       NaN
# 323        Grain Technology                        NaN      NaN       NaN
# 329        BlueReceipt                             NaN      NaN       NaN
# 341        One Two Smile                           NaN      NaN       NaN
# 343        Invoice2Go                              NaN      NaN       NaN
# 344        Build A Sign                            NaN      NaN       NaN
# 370        Wirewax                                 NaN      NaN       NaN
#
#                                                                             \
# date                                             6/17/20   6/18/20 6/19/20
# account_id account_name
# 2          Hoss                                      NaN       NaN     NaN
# 15         João                                      NaN       NaN     NaN
# 17         bertelli.dev                              NaN       NaN     NaN
# 18         Linh                                      NaN       NaN     NaN
# 20         Zen Business PBC                       3456.0    2978.0  2047.0
# 22         Hamza Zia                               109.0      39.0  1585.0
# 25         Jeremy Evans                          19503.0    2104.0     NaN
# 26         26                                        NaN       NaN     NaN
# 30         Hoss                                  11689.0   16498.0  2423.0
# 33         Trung                                     NaN       NaN     NaN
# 34         Hoss Test                                 NaN       NaN     NaN
# 37         test                                      NaN       NaN     NaN
# 39         Hoss                                      NaN       NaN     NaN
# 40         hoss                                      NaN       NaN     NaN
# 41         zfaeel+10@gmail.com                       NaN       NaN     NaN
# 46         hoss                                      NaN       NaN     NaN
# 59         Lakestar                                 54.0      72.0    48.0
# 79         Carpe Diem                                NaN       NaN     NaN
# 90         Hoss Prod4                                NaN       NaN     NaN
# 104        Abstraction Capital                      89.0       NaN     NaN
# 111        Hive                                      NaN       NaN     NaN
# 112        Gordian Software Inc.                     NaN       NaN     NaN
# 115        YearEnd, Inc.                             NaN     467.0   178.0
# 121        LeoEK                                     NaN       NaN     NaN
# 130        Swishify                                204.0     256.0   238.0
# 137        Courier                                   NaN       NaN     NaN
# 176        Ripplink                             331984.0  426737.0     NaN
# 201        DMC                                     189.0     677.0   148.0
# 215        test                                  31787.0       NaN     NaN
# 242        Signzy Technologies Private Limited       NaN       NaN     NaN
# 253        pbp                                       NaN       NaN     NaN
# 256        Self                                      NaN       NaN     NaN
# 270        Blair                                     NaN       NaN     NaN
# 277        Buttondown                                NaN       NaN     NaN
# 291        Hoss                                      NaN       NaN     NaN
# 295        Meadow                                    NaN       NaN     NaN
# 311        beaverlang                                NaN       NaN     NaN
# 320        ZIGGURAT INTERNATIONAL                    NaN       NaN     NaN
# 323        Grain Technology                          NaN       NaN     NaN
# 329        BlueReceipt                               NaN       NaN     NaN
# 341        One Two Smile                             NaN       NaN     NaN
# 343        Invoice2Go                                NaN       NaN     NaN
# 344        Build A Sign                              NaN       NaN     NaN
# 370        Wirewax                                   NaN       NaN     NaN
#
#                                                         ...            \
# date                                           6/20/20  ...   8/30/20
# account_id account_name                                 ...
# 2          Hoss                                    NaN  ...       NaN
# 15         João                                    NaN  ...       NaN
# 17         bertelli.dev                            NaN  ...       NaN
# 18         Linh                                    NaN  ...       NaN
# 20         Zen Business PBC                     2042.0  ...    5122.0
# 22         Hamza Zia                               NaN  ...    3825.0
# 25         Jeremy Evans                            NaN  ...   13205.0
# 26         26                                      NaN  ...       NaN
# 30         Hoss                                 1496.0  ...  121017.0
# 33         Trung                                   NaN  ...       NaN
# 34         Hoss Test                               NaN  ...       NaN
# 37         test                                    NaN  ...       NaN
# 39         Hoss                                    NaN  ...       NaN
# 40         hoss                                    NaN  ...       NaN
# 41         zfaeel+10@gmail.com                     NaN  ...       NaN
# 46         hoss                                    NaN  ...       NaN
# 59         Lakestar                                6.0  ...       NaN
# 79         Carpe Diem                              NaN  ...       NaN
# 90         Hoss Prod4                              NaN  ...       NaN
# 104        Abstraction Capital                     NaN  ...       NaN
# 111        Hive                                    NaN  ...       NaN
# 112        Gordian Software Inc.                   NaN  ...       NaN
# 115        YearEnd, Inc.                         152.0  ...       NaN
# 121        LeoEK                                   NaN  ...       NaN
# 130        Swishify                               93.0  ...       NaN
# 137        Courier                                 NaN  ...   10990.0
# 176        Ripplink                                NaN  ...       NaN
# 201        DMC                                   124.0  ...   81191.0
# 215        test                                    NaN  ...       NaN
# 242        Signzy Technologies Private Limited     NaN  ...       NaN
# 253        pbp                                     NaN  ...       NaN
# 256        Self                                    NaN  ...  113896.0
# 270        Blair                                   NaN  ...       NaN
# 277        Buttondown                              NaN  ...       NaN
# 291        Hoss                                    NaN  ...       NaN
# 295        Meadow                                  NaN  ...       NaN
# 311        beaverlang                              NaN  ...       NaN
# 320        ZIGGURAT INTERNATIONAL                  NaN  ...    4354.0
# 323        Grain Technology                        NaN  ...  473695.0
# 329        BlueReceipt                             NaN  ...       NaN
# 341        One Two Smile                           NaN  ...   29120.0
# 343        Invoice2Go                              NaN  ...       NaN
# 344        Build A Sign                            NaN  ...       NaN
# 370        Wirewax                                 NaN  ...       NaN
#
#                                                                               \
# date                                             8/31/20    8/9/20    9/1/20
# account_id account_name
# 2          Hoss                                      NaN       NaN       NaN
# 15         João                                      NaN       NaN       NaN
# 17         bertelli.dev                              NaN       NaN       NaN
# 18         Linh                                      NaN       NaN       NaN
# 20         Zen Business PBC                       8043.0    3734.0    7661.0
# 22         Hamza Zia                             12033.0   20602.0    9863.0
# 25         Jeremy Evans                          18106.0   25834.0   19509.0
# 26         26                                        NaN       NaN       NaN
# 30         Hoss                                 121790.0  117557.0  122708.0
# 33         Trung                                     NaN       NaN       NaN
# 34         Hoss Test                                 NaN       NaN       NaN
# 37         test                                      NaN       NaN       NaN
# 39         Hoss                                      NaN       NaN       NaN
# 40         hoss                                      NaN       NaN       NaN
# 41         zfaeel+10@gmail.com                       NaN       NaN       NaN
# 46         hoss                                      NaN       NaN       NaN
# 59         Lakestar                                  NaN       NaN       NaN
# 79         Carpe Diem                                NaN       NaN       NaN
# 90         Hoss Prod4                                NaN       NaN       NaN
# 104        Abstraction Capital                       NaN       NaN       NaN
# 111        Hive                                      NaN       NaN       NaN
# 112        Gordian Software Inc.                     NaN       NaN       NaN
# 115        YearEnd, Inc.                             NaN      55.0       NaN
# 121        LeoEK                                     NaN       NaN       NaN
# 130        Swishify                                  NaN       NaN       NaN
# 137        Courier                               39915.0   21653.0   13376.0
# 176        Ripplink                                  NaN       NaN       NaN
# 201        DMC                                   81471.0   71691.0   80074.0
# 215        test                                      NaN       NaN       NaN
# 242        Signzy Technologies Private Limited       NaN       NaN       NaN
# 253        pbp                                       NaN       NaN       NaN
# 256        Self                                 115015.0       NaN  117853.0
# 270        Blair                                 21495.0     108.0    5621.0
# 277        Buttondown                                NaN       NaN       NaN
# 291        Hoss                                      NaN       NaN       NaN
# 295        Meadow                                    NaN       NaN       NaN
# 311        beaverlang                                NaN      87.0       NaN
# 320        ZIGGURAT INTERNATIONAL                    NaN       NaN       NaN
# 323        Grain Technology                     578704.0  431597.0  615936.0
# 329        BlueReceipt                               NaN       NaN       NaN
# 341        One Two Smile                         18376.0       NaN   22130.0
# 343        Invoice2Go                                NaN       NaN       NaN
# 344        Build A Sign                              NaN       NaN       NaN
# 370        Wirewax                                   NaN       NaN       NaN
#
#                                                                               \
# date                                              9/2/20    9/3/20    9/4/20
# account_id account_name
# 2          Hoss                                      NaN       NaN       NaN
# 15         João                                      NaN       NaN       NaN
# 17         bertelli.dev                              NaN       NaN       NaN
# 18         Linh                                      NaN       NaN       NaN
# 20         Zen Business PBC                       9582.0    6945.0    6170.0
# 22         Hamza Zia                             12824.0   11385.0    9939.0
# 25         Jeremy Evans                          20194.0   24496.0   17237.0
# 26         26                                        NaN       NaN       NaN
# 30         Hoss                                 125561.0  124715.0  124597.0
# 33         Trung                                     NaN       NaN       NaN
# 34         Hoss Test                                 NaN       NaN       NaN
# 37         test                                      NaN       NaN       NaN
# 39         Hoss                                      NaN       NaN       NaN
# 40         hoss                                      NaN       NaN       NaN
# 41         zfaeel+10@gmail.com                       NaN       NaN       NaN
# 46         hoss                                      NaN       NaN       NaN
# 59         Lakestar                                  NaN       NaN       NaN
# 79         Carpe Diem                                NaN       NaN       NaN
# 90         Hoss Prod4                                NaN       NaN       NaN
# 104        Abstraction Capital                       NaN       NaN       NaN
# 111        Hive                                      NaN       NaN       NaN
# 112        Gordian Software Inc.                     NaN       NaN       NaN
# 115        YearEnd, Inc.                             NaN       NaN       NaN
# 121        LeoEK                                     NaN       NaN       NaN
# 130        Swishify                                  NaN       NaN       NaN
# 137        Courier                               20099.0   29223.0   13649.0
# 176        Ripplink                                  NaN       NaN       NaN
# 201        DMC                                  119424.0  128845.0  128171.0
# 215        test                                      NaN       NaN       NaN
# 242        Signzy Technologies Private Limited       NaN       NaN       NaN
# 253        pbp                                       NaN       NaN       NaN
# 256        Self                                 124707.0  113410.0  109966.0
# 270        Blair                                     NaN       NaN       NaN
# 277        Buttondown                                NaN       NaN       NaN
# 291        Hoss                                      NaN       NaN       NaN
# 295        Meadow                                    NaN       NaN       NaN
# 311        beaverlang                                NaN       NaN       NaN
# 320        ZIGGURAT INTERNATIONAL                 4331.0   57378.0  691452.0
# 323        Grain Technology                     567010.0  880629.0  912103.0
# 329        BlueReceipt                               NaN       NaN       NaN
# 341        One Two Smile                         16491.0   17157.0   13089.0
# 343        Invoice2Go                                NaN       NaN       NaN
# 344        Build A Sign                              NaN       NaN       NaN
# 370        Wirewax                                   NaN       NaN       NaN
#
#
# date                                              9/5/20    9/6/20    9/7/20
# account_id account_name
# 2          Hoss                                      NaN       NaN       NaN
# 15         João                                      NaN       NaN       NaN
# 17         bertelli.dev                              NaN       NaN       NaN
# 18         Linh                                      NaN       NaN       NaN
# 20         Zen Business PBC                       5324.0    5129.0    5572.0
# 22         Hamza Zia                              4227.0    6613.0   11031.0
# 25         Jeremy Evans                          11114.0   11105.0   19533.0
# 26         26                                        NaN       NaN       NaN
# 30         Hoss                                 123972.0  123053.0  125683.0
# 33         Trung                                     NaN       NaN       NaN
# 34         Hoss Test                                 NaN       NaN       NaN
# 37         test                                      NaN       NaN       NaN
# 39         Hoss                                      NaN       NaN       NaN
# 40         hoss                                      NaN       NaN       NaN
# 41         zfaeel+10@gmail.com                       NaN       NaN       NaN
# 46         hoss                                      NaN       NaN       NaN
# 59         Lakestar                                  NaN       NaN       NaN
# 79         Carpe Diem                                NaN       NaN       NaN
# 90         Hoss Prod4                                NaN       NaN       NaN
# 104        Abstraction Capital                       NaN       NaN       NaN
# 111        Hive                                      NaN       NaN       NaN
# 112        Gordian Software Inc.                     NaN       NaN       NaN
# 115        YearEnd, Inc.                          1792.0     114.0       NaN
# 121        LeoEK                                     NaN       NaN       NaN
# 130        Swishify                                  NaN       NaN       NaN
# 137        Courier                                7897.0    6094.0   12086.0
# 176        Ripplink                                  NaN       NaN       NaN
# 201        DMC                                  131493.0  124924.0  117169.0
# 215        test                                      NaN       NaN       NaN
# 242        Signzy Technologies Private Limited       NaN       NaN       NaN
# 253        pbp                                       NaN       NaN       NaN
# 256        Self                                 110329.0  115700.0  114073.0
# 270        Blair                                     NaN       NaN       NaN
# 277        Buttondown                                NaN       NaN       NaN
# 291        Hoss                                      NaN       NaN       NaN
# 295        Meadow                                    NaN       NaN       NaN
# 311        beaverlang                                NaN       NaN       NaN
# 320        ZIGGURAT INTERNATIONAL                    NaN       NaN    1455.0
# 323        Grain Technology                     495412.0  450530.0  473199.0
# 329        BlueReceipt                               NaN       NaN       NaN
# 341        One Two Smile                         14992.0   20946.0   21624.0
# 343        Invoice2Go                                NaN       NaN       NaN
# 344        Build A Sign                              NaN       NaN       NaN
# 370        Wirewax                                   NaN       NaN       NaN
#
# [44 rows x 84 columns]

# %%
# Sort the table by descending requests 
daily_request['total_request']= daily_request.sum(axis= 1)
daily_request_sorted= daily_request.sort_values(by= ['total_request'], ascending= False)
daily_request_sorted
# Out:
#                                                requests                    \
# date                                            6/11/20  6/12/20  6/13/20
# account_id account_name
# 323        Grain Technology                         NaN      NaN      NaN
# 30         Hoss                                   101.0     23.0      1.0
# 201        DMC                                      NaN      NaN      NaN
# 320        ZIGGURAT INTERNATIONAL                   NaN      NaN      NaN
# 256        Self                                     NaN      NaN      NaN
# 25         Jeremy Evans                         11973.0  11178.0  10669.0
# 22         Hamza Zia                                3.0    111.0      NaN
# 137        Courier                                  NaN      NaN      NaN
# 270        Blair                                    NaN      NaN      NaN
# 176        Ripplink                                 NaN      NaN      NaN
# 20         Zen Business PBC                      2497.0   2308.0   2200.0
# 341        One Two Smile                            NaN      NaN      NaN
# 343        Invoice2Go                               NaN      NaN      NaN
# 215        test                                     NaN      NaN      NaN
# 115        YearEnd, Inc.                            NaN      NaN      NaN
# 130        Swishify                                 NaN      NaN      NaN
# 311        beaverlang                               NaN      NaN      NaN
# 59         Lakestar                                 NaN      NaN      NaN
# 370        Wirewax                                  NaN      NaN      NaN
# 277        Buttondown                               NaN      NaN      NaN
# 111        Hive                                     NaN      NaN      NaN
# 344        Build A Sign                             NaN      NaN      NaN
# 329        BlueReceipt                              NaN      NaN      NaN
# 242        Signzy Technologies Private Limited      NaN      NaN      NaN
# 2          Hoss                                    11.0      NaN      NaN
# 104        Abstraction Capital                      NaN      NaN      NaN
# 26         26                                     121.0      NaN      NaN
# 79         Carpe Diem                               NaN      NaN      NaN
# 15         João                                     NaN      NaN      NaN
# 121        LeoEK                                    NaN      NaN      NaN
# 295        Meadow                                   NaN      NaN      NaN
# 253        pbp                                      NaN      NaN      NaN
# 46         hoss                                     NaN      NaN      NaN
# 90         Hoss Prod4                               NaN      NaN      NaN
# 17         bertelli.dev                             5.0      NaN      NaN
# 18         Linh                                     NaN      NaN      NaN
# 112        Gordian Software Inc.                    NaN      NaN      NaN
# 33         Trung                                    NaN      NaN      NaN
# 37         test                                     NaN      NaN      NaN
# 291        Hoss                                     NaN      NaN      NaN
# 41         zfaeel+10@gmail.com                      NaN      NaN      NaN
# 34         Hoss Test                                NaN      NaN      NaN
# 40         hoss                                     NaN      NaN      NaN
# 39         Hoss                                     NaN      NaN      NaN
#
#                                                                            \
# date                                           6/14/20  6/15/20   6/16/20
# account_id account_name
# 323        Grain Technology                        NaN      NaN       NaN
# 30         Hoss                                 2924.0  13364.0   15012.0
# 201        DMC                                     NaN      NaN      93.0
# 320        ZIGGURAT INTERNATIONAL                  NaN      NaN       NaN
# 256        Self                                    NaN      NaN       NaN
# 25         Jeremy Evans                         9862.0  11797.0   19965.0
# 22         Hamza Zia                               NaN   8804.0   16465.0
# 137        Courier                                 NaN      NaN       NaN
# 270        Blair                                   NaN      NaN       NaN
# 176        Ripplink                                NaN      NaN  189280.0
# 20         Zen Business PBC                     2071.0   2679.0    5037.0
# 341        One Two Smile                           NaN      NaN       NaN
# 343        Invoice2Go                              NaN      NaN       NaN
# 215        test                                    NaN      NaN    9000.0
# 115        YearEnd, Inc.                           NaN    127.0       NaN
# 130        Swishify                                NaN      NaN     265.0
# 311        beaverlang                              NaN      NaN       NaN
# 59         Lakestar                                NaN      NaN      14.0
# 370        Wirewax                                 NaN      NaN       NaN
# 277        Buttondown                              NaN      NaN       NaN
# 111        Hive                                    NaN   2217.0       NaN
# 344        Build A Sign                            NaN      NaN       NaN
# 329        BlueReceipt                             NaN      NaN       NaN
# 242        Signzy Technologies Private Limited     NaN      NaN       NaN
# 2          Hoss                                    NaN      NaN       NaN
# 104        Abstraction Capital                     NaN     41.0       NaN
# 26         26                                      NaN      NaN       NaN
# 79         Carpe Diem                              NaN     94.0       NaN
# 15         João                                    NaN      NaN       NaN
# 121        LeoEK                                   NaN     29.0       NaN
# 295        Meadow                                  NaN      NaN       NaN
# 253        pbp                                     NaN      NaN       NaN
# 46         hoss                                    2.0     15.0       NaN
# 90         Hoss Prod4                              NaN      NaN       NaN
# 17         bertelli.dev                            NaN      NaN       NaN
# 18         Linh                                    NaN      NaN       NaN
# 112        Gordian Software Inc.                   NaN      NaN       7.0
# 33         Trung                                   5.0      NaN       NaN
# 37         test                                    1.0      NaN       NaN
# 291        Hoss                                    NaN      NaN       NaN
# 41         zfaeel+10@gmail.com                     1.0      NaN       NaN
# 34         Hoss Test                               1.0      NaN       NaN
# 40         hoss                                    1.0      NaN       NaN
# 39         Hoss                                    1.0      NaN       NaN
#
#                                                                             \
# date                                             6/17/20   6/18/20 6/19/20
# account_id account_name
# 323        Grain Technology                          NaN       NaN     NaN
# 30         Hoss                                  11689.0   16498.0  2423.0
# 201        DMC                                     189.0     677.0   148.0
# 320        ZIGGURAT INTERNATIONAL                    NaN       NaN     NaN
# 256        Self                                      NaN       NaN     NaN
# 25         Jeremy Evans                          19503.0    2104.0     NaN
# 22         Hamza Zia                               109.0      39.0  1585.0
# 137        Courier                                   NaN       NaN     NaN
# 270        Blair                                     NaN       NaN     NaN
# 176        Ripplink                             331984.0  426737.0     NaN
# 20         Zen Business PBC                       3456.0    2978.0  2047.0
# 341        One Two Smile                             NaN       NaN     NaN
# 343        Invoice2Go                                NaN       NaN     NaN
# 215        test                                  31787.0       NaN     NaN
# 115        YearEnd, Inc.                             NaN     467.0   178.0
# 130        Swishify                                204.0     256.0   238.0
# 311        beaverlang                                NaN       NaN     NaN
# 59         Lakestar                                 54.0      72.0    48.0
# 370        Wirewax                                   NaN       NaN     NaN
# 277        Buttondown                                NaN       NaN     NaN
# 111        Hive                                      NaN       NaN     NaN
# 344        Build A Sign                              NaN       NaN     NaN
# 329        BlueReceipt                               NaN       NaN     NaN
# 242        Signzy Technologies Private Limited       NaN       NaN     NaN
# 2          Hoss                                      NaN       NaN     NaN
# 104        Abstraction Capital                      89.0       NaN     NaN
# 26         26                                        NaN       NaN     NaN
# 79         Carpe Diem                                NaN       NaN     NaN
# 15         João                                      NaN       NaN     NaN
# 121        LeoEK                                     NaN       NaN     NaN
# 295        Meadow                                    NaN       NaN     NaN
# 253        pbp                                       NaN       NaN     NaN
# 46         hoss                                      NaN       NaN     NaN
# 90         Hoss Prod4                                NaN       NaN     NaN
# 17         bertelli.dev                              NaN       NaN     NaN
# 18         Linh                                      NaN       NaN     NaN
# 112        Gordian Software Inc.                     NaN       NaN     NaN
# 33         Trung                                     NaN       NaN     NaN
# 37         test                                      NaN       NaN     NaN
# 291        Hoss                                      NaN       NaN     NaN
# 41         zfaeel+10@gmail.com                       NaN       NaN     NaN
# 34         Hoss Test                                 NaN       NaN     NaN
# 40         hoss                                      NaN       NaN     NaN
# 39         Hoss                                      NaN       NaN     NaN
#
#                                                         ...            \
# date                                           6/20/20  ...   8/31/20
# account_id account_name                                 ...
# 323        Grain Technology                        NaN  ...  578704.0
# 30         Hoss                                 1496.0  ...  121790.0
# 201        DMC                                   124.0  ...   81471.0
# 320        ZIGGURAT INTERNATIONAL                  NaN  ...       NaN
# 256        Self                                    NaN  ...  115015.0
# 25         Jeremy Evans                            NaN  ...   18106.0
# 22         Hamza Zia                               NaN  ...   12033.0
# 137        Courier                                 NaN  ...   39915.0
# 270        Blair                                   NaN  ...   21495.0
# 176        Ripplink                                NaN  ...       NaN
# 20         Zen Business PBC                     2042.0  ...    8043.0
# 341        One Two Smile                           NaN  ...   18376.0
# 343        Invoice2Go                              NaN  ...       NaN
# 215        test                                    NaN  ...       NaN
# 115        YearEnd, Inc.                         152.0  ...       NaN
# 130        Swishify                               93.0  ...       NaN
# 311        beaverlang                              NaN  ...       NaN
# 59         Lakestar                                6.0  ...       NaN
# 370        Wirewax                                 NaN  ...       NaN
# 277        Buttondown                              NaN  ...       NaN
# 111        Hive                                    NaN  ...       NaN
# 344        Build A Sign                            NaN  ...       NaN
# 329        BlueReceipt                             NaN  ...       NaN
# 242        Signzy Technologies Private Limited     NaN  ...       NaN
# 2          Hoss                                    NaN  ...       NaN
# 104        Abstraction Capital                     NaN  ...       NaN
# 26         26                                      NaN  ...       NaN
# 79         Carpe Diem                              NaN  ...       NaN
# 15         João                                    NaN  ...       NaN
# 121        LeoEK                                   NaN  ...       NaN
# 295        Meadow                                  NaN  ...       NaN
# 253        pbp                                     NaN  ...       NaN
# 46         hoss                                    NaN  ...       NaN
# 90         Hoss Prod4                              NaN  ...       NaN
# 17         bertelli.dev                            NaN  ...       NaN
# 18         Linh                                    NaN  ...       NaN
# 112        Gordian Software Inc.                   NaN  ...       NaN
# 33         Trung                                   NaN  ...       NaN
# 37         test                                    NaN  ...       NaN
# 291        Hoss                                    NaN  ...       NaN
# 41         zfaeel+10@gmail.com                     NaN  ...       NaN
# 34         Hoss Test                               NaN  ...       NaN
# 40         hoss                                    NaN  ...       NaN
# 39         Hoss                                    NaN  ...       NaN
#
#                                                                               \
# date                                              8/9/20    9/1/20    9/2/20
# account_id account_name
# 323        Grain Technology                     431597.0  615936.0  567010.0
# 30         Hoss                                 117557.0  122708.0  125561.0
# 201        DMC                                   71691.0   80074.0  119424.0
# 320        ZIGGURAT INTERNATIONAL                    NaN       NaN    4331.0
# 256        Self                                      NaN  117853.0  124707.0
# 25         Jeremy Evans                          25834.0   19509.0   20194.0
# 22         Hamza Zia                             20602.0    9863.0   12824.0
# 137        Courier                               21653.0   13376.0   20099.0
# 270        Blair                                   108.0    5621.0       NaN
# 176        Ripplink                                  NaN       NaN       NaN
# 20         Zen Business PBC                       3734.0    7661.0    9582.0
# 341        One Two Smile                             NaN   22130.0   16491.0
# 343        Invoice2Go                                NaN       NaN       NaN
# 215        test                                      NaN       NaN       NaN
# 115        YearEnd, Inc.                            55.0       NaN       NaN
# 130        Swishify                                  NaN       NaN       NaN
# 311        beaverlang                               87.0       NaN       NaN
# 59         Lakestar                                  NaN       NaN       NaN
# 370        Wirewax                                   NaN       NaN       NaN
# 277        Buttondown                                NaN       NaN       NaN
# 111        Hive                                      NaN       NaN       NaN
# 344        Build A Sign                              NaN       NaN       NaN
# 329        BlueReceipt                               NaN       NaN       NaN
# 242        Signzy Technologies Private Limited       NaN       NaN       NaN
# 2          Hoss                                      NaN       NaN       NaN
# 104        Abstraction Capital                       NaN       NaN       NaN
# 26         26                                        NaN       NaN       NaN
# 79         Carpe Diem                                NaN       NaN       NaN
# 15         João                                      NaN       NaN       NaN
# 121        LeoEK                                     NaN       NaN       NaN
# 295        Meadow                                    NaN       NaN       NaN
# 253        pbp                                       NaN       NaN       NaN
# 46         hoss                                      NaN       NaN       NaN
# 90         Hoss Prod4                                NaN       NaN       NaN
# 17         bertelli.dev                              NaN       NaN       NaN
# 18         Linh                                      NaN       NaN       NaN
# 112        Gordian Software Inc.                     NaN       NaN       NaN
# 33         Trung                                     NaN       NaN       NaN
# 37         test                                      NaN       NaN       NaN
# 291        Hoss                                      NaN       NaN       NaN
# 41         zfaeel+10@gmail.com                       NaN       NaN       NaN
# 34         Hoss Test                                 NaN       NaN       NaN
# 40         hoss                                      NaN       NaN       NaN
# 39         Hoss                                      NaN       NaN       NaN
#
#                                                                               \
# date                                              9/3/20    9/4/20    9/5/20
# account_id account_name
# 323        Grain Technology                     880629.0  912103.0  495412.0
# 30         Hoss                                 124715.0  124597.0  123972.0
# 201        DMC                                  128845.0  128171.0  131493.0
# 320        ZIGGURAT INTERNATIONAL                57378.0  691452.0       NaN
# 256        Self                                 113410.0  109966.0  110329.0
# 25         Jeremy Evans                          24496.0   17237.0   11114.0
# 22         Hamza Zia                             11385.0    9939.0    4227.0
# 137        Courier                               29223.0   13649.0    7897.0
# 270        Blair                                     NaN       NaN       NaN
# 176        Ripplink                                  NaN       NaN       NaN
# 20         Zen Business PBC                       6945.0    6170.0    5324.0
# 341        One Two Smile                         17157.0   13089.0   14992.0
# 343        Invoice2Go                                NaN       NaN       NaN
# 215        test                                      NaN       NaN       NaN
# 115        YearEnd, Inc.                             NaN       NaN    1792.0
# 130        Swishify                                  NaN       NaN       NaN
# 311        beaverlang                                NaN       NaN       NaN
# 59         Lakestar                                  NaN       NaN       NaN
# 370        Wirewax                                   NaN       NaN       NaN
# 277        Buttondown                                NaN       NaN       NaN
# 111        Hive                                      NaN       NaN       NaN
# 344        Build A Sign                              NaN       NaN       NaN
# 329        BlueReceipt                               NaN       NaN       NaN
# 242        Signzy Technologies Private Limited       NaN       NaN       NaN
# 2          Hoss                                      NaN       NaN       NaN
# 104        Abstraction Capital                       NaN       NaN       NaN
# 26         26                                        NaN       NaN       NaN
# 79         Carpe Diem                                NaN       NaN       NaN
# 15         João                                      NaN       NaN       NaN
# 121        LeoEK                                     NaN       NaN       NaN
# 295        Meadow                                    NaN       NaN       NaN
# 253        pbp                                       NaN       NaN       NaN
# 46         hoss                                      NaN       NaN       NaN
# 90         Hoss Prod4                                NaN       NaN       NaN
# 17         bertelli.dev                              NaN       NaN       NaN
# 18         Linh                                      NaN       NaN       NaN
# 112        Gordian Software Inc.                     NaN       NaN       NaN
# 33         Trung                                     NaN       NaN       NaN
# 37         test                                      NaN       NaN       NaN
# 291        Hoss                                      NaN       NaN       NaN
# 41         zfaeel+10@gmail.com                       NaN       NaN       NaN
# 34         Hoss Test                                 NaN       NaN       NaN
# 40         hoss                                      NaN       NaN       NaN
# 39         Hoss                                      NaN       NaN       NaN
#
#                                                                     \
# date                                              9/6/20    9/7/20
# account_id account_name
# 323        Grain Technology                     450530.0  473199.0
# 30         Hoss                                 123053.0  125683.0
# 201        DMC                                  124924.0  117169.0
# 320        ZIGGURAT INTERNATIONAL                    NaN    1455.0
# 256        Self                                 115700.0  114073.0
# 25         Jeremy Evans                          11105.0   19533.0
# 22         Hamza Zia                              6613.0   11031.0
# 137        Courier                                6094.0   12086.0
# 270        Blair                                     NaN       NaN
# 176        Ripplink                                  NaN       NaN
# 20         Zen Business PBC                       5129.0    5572.0
# 341        One Two Smile                         20946.0   21624.0
# 343        Invoice2Go                                NaN       NaN
# 215        test                                      NaN       NaN
# 115        YearEnd, Inc.                           114.0       NaN
# 130        Swishify                                  NaN       NaN
# 311        beaverlang                                NaN       NaN
# 59         Lakestar                                  NaN       NaN
# 370        Wirewax                                   NaN       NaN
# 277        Buttondown                                NaN       NaN
# 111        Hive                                      NaN       NaN
# 344        Build A Sign                              NaN       NaN
# 329        BlueReceipt                               NaN       NaN
# 242        Signzy Technologies Private Limited       NaN       NaN
# 2          Hoss                                      NaN       NaN
# 104        Abstraction Capital                       NaN       NaN
# 26         26                                        NaN       NaN
# 79         Carpe Diem                                NaN       NaN
# 15         João                                      NaN       NaN
# 121        LeoEK                                     NaN       NaN
# 295        Meadow                                    NaN       NaN
# 253        pbp                                       NaN       NaN
# 46         hoss                                      NaN       NaN
# 90         Hoss Prod4                                NaN       NaN
# 17         bertelli.dev                              NaN       NaN
# 18         Linh                                      NaN       NaN
# 112        Gordian Software Inc.                     NaN       NaN
# 33         Trung                                     NaN       NaN
# 37         test                                      NaN       NaN
# 291        Hoss                                      NaN       NaN
# 41         zfaeel+10@gmail.com                       NaN       NaN
# 34         Hoss Test                                 NaN       NaN
# 40         hoss                                      NaN       NaN
# 39         Hoss                                      NaN       NaN
#
#                                                total_request
# date
# account_id account_name
# 323        Grain Technology                       20932721.0
# 30         Hoss                                    6878231.0
# 201        DMC                                     3315581.0
# 320        ZIGGURAT INTERNATIONAL                  2798356.0
# 256        Self                                    1708429.0
# 25         Jeremy Evans                            1630706.0
# 22         Hamza Zia                               1400389.0
# 137        Courier                                 1398969.0
# 270        Blair                                   1116982.0
# 176        Ripplink                                 948001.0
# 20         Zen Business PBC                         493470.0
# 341        One Two Smile                            341144.0
# 343        Invoice2Go                                44353.0
# 215        test                                      40787.0
# 115        YearEnd, Inc.                             39881.0
# 130        Swishify                                  12286.0
# 311        beaverlang                                 9099.0
# 59         Lakestar                                   3677.0
# 370        Wirewax                                    3369.0
# 277        Buttondown                                 3231.0
# 111        Hive                                       2217.0
# 344        Build A Sign                               1745.0
# 329        BlueReceipt                                 385.0
# 242        Signzy Technologies Private Limited         368.0
# 2          Hoss                                        207.0
# 104        Abstraction Capital                         194.0
# 26         26                                          121.0
# 79         Carpe Diem                                   94.0
# 15         João                                         33.0
# 121        LeoEK                                        29.0
# 295        Meadow                                       24.0
# 253        pbp                                          18.0
# 46         hoss                                         17.0
# 90         Hoss Prod4                                   13.0
# 17         bertelli.dev                                 11.0
# 18         Linh                                          7.0
# 112        Gordian Software Inc.                         7.0
# 33         Trung                                         5.0
# 37         test                                          1.0
# 291        Hoss                                          1.0
# 41         zfaeel+10@gmail.com                           1.0
# 34         Hoss Test                                     1.0
# 40         hoss                                          1.0
# 39         Hoss                                          1.0
#
# [44 rows x 85 columns]

# %%
# Hightlight the result with color palette
cm = sns.light_palette('green', as_cmap=True)
table = daily_request_sorted.style.background_gradient(cmap=cm)\
.highlight_null(null_color='white')\
.format('{0:,.0f}',na_rep= '')\
.set_caption('No. of daily request by Account')\
.set_table_styles([{
    'selector': 'caption',
    'props': [('color', 'black'), ('font-size', '18px')]}])\
.set_properties(**{'border-color': 'black','text-align': 'center','border-width':'thin','border-style':'dotted'})
table
# Out:
# <style  type="text/css" >
#     #T_71ee24b2_f9f6_11ea_93be_acde48001122 caption {
#           color: black;
#           font-size: 18px;
#     }    #T_71ee24b2_f9f6_11ea_93be_acde48001122row0_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#             border-color:  black;
#             text-align:  center;
#             border-width:  thin;
#             border-style:  dotted;
#         }    #T_71ee24b2_f9f6_11ea_93be_acde48001122row0_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#             border-color:  black;
#             text-align:  center;
#             border-width:  thin;
#             border-style:  dotted;
#         }    #T_71ee24b2_f9f6_11ea_93be_acde48001122row0_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#             border-color:  black;
#             text-align:  center;
#             border-width:  thin;
#             border-style:  dotted;
#         }    #T_71ee24b2_f9f6_11ea_93be_acde48001122row0_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#             border-color:  black;
#             text-align:  center;
#             border-width:  thin;
#             border-style:  dotted;
#         }    #T_71ee24b2_f9f6_11ea_93be_acde48001122row0_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#             border-color:  black;
#             text-align:  center;
#             border-width:  thin;
#             border-style:  dotted;
#         }    #T_71ee24b2_f9f6_11ea_93be_acde48001122row0_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#             border-color:  black;
#             text-align:  center;
#             border-width:  thin;
#             border-style:  dotted;
#         }    #T_71ee24b2_f9f6_11ea_93be_acde48001122row0_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#             border-color:  black;
#             text-align:  center;
#             border-width:  thin;
#             border-style:  dotted;
#         }    #T_71ee24b2_f9f6_11ea_93be_acde48001122row0_col7 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#             border-color:  black;
#             text-align:  center;
#             border-width:  thin;
#             border-style:  dotted;
#         }    #T_71ee24b2_f9f6_11ea_93be_acde48001122row0_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#             border-color:  black;
#             text-align:  center;
#             border-width:  thin;
#             border-style:  dotted;
#         }    #T_71ee24b2_f9f6_11ea_93be_acde48001122row0_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#             border-color:  black;
#             text-align:  center;
#             border-width:  thin;
#             border-style:  dotted;
#         }    #T_71ee24b2_f9f6_11ea_93be_acde48001122row0_col10 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#             border-color:  black;
#             text-align:  center;
#             border-width:  thin;
#             border-style:  dotted;
#         }    #T_71ee24b2_f9f6_11ea_93be_acde48001122row0_col11 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#             border-color:  black;
#             text-align:  center;
#             border-width:  thin;
#             border-style:  dotted;
#         }    #T_71ee24b2_f9f6_11ea_93be_acde48001122row0_col12 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#             border-color:  black;
#             text-align:  center;
#             border-width:  thin;
#             border-style:  dotted;
#         }    #T_71ee24b2_f9f6_11ea_93be_acde48001122row0_col13 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#             border-color:  black;
#             text-align:  center;
#             border-width:  thin;
#             border-style:  dotted;
#         }    #T_71ee24b2_f9f6_11ea_93be_acde48001122row0_col14 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#             border-color:  black;
#             text-align:  center;
#             border-width:  thin;
#             border-style:  dotted;
#         }    #T_71ee24b2_f9f6_11ea_93be_acde48001122row0_col15 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#             border-color:  black;
#             text-align:  center;
#             border-width:  thin;
#             border-style:  dotted;
#         }    #T_71ee24b2_f9f6_11ea_93be_acde48001122row0_col16 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#             border-color:  black;
#             text-align:  center;
#             border-width:  thin;
#             border-style:  dotted;
#         }    #T_71ee24b2_f9f6_11ea_93be_acde48001122row0_col17 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#             border-color:  black;
#             text-align:  center;
#             border-width:  thin;
#             border-style:  dotted;
#         }    #T_71ee24b2_f9f6_11ea_93be_acde48001122row0_col18 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#             border-color:  black;
#             text-align:  center;
#             border-width:  thin;
#             border-style:  dotted;
#         }    #T_71ee24b2_f9f6_11ea_93be_acde48001122row0_col19 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#             border-color:  black;
#             text-align:  center;
#             border-width:  thin;
#             border-style:  dotted;
#         }    #T_71ee24b2_f9f6_11ea_93be_acde48001122row0_col20 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#             border-color:  black;
#             text-align:  center;
#             border-width:  thin;
#             border-style:  dotted;
#         }    #T_71ee24b2_f9f6_11ea_93be_acde48001122row0_col21 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#             border-color:  black;
#             text-align:  center;
#             border-width:  thin;
#             border-style:  dotted;
#         }    #T_71ee24b2_f9f6_11ea_93be_acde48001122row0_col22 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#             border-color:  black;
#             text-align:  center;
#             border-width:  thin;
#             border-style:  dotted;
#         }    #T_71ee24b2_f9f6_11ea_93be_acde48001122row0_col23 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#             border-color:  black;
#             text-align:  center;
#             border-width:  thin;
#             border-style:  dotted;
#         }    #T_71ee24b2_f9f6_11ea_93be_acde48001122row0_col24 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#             border-color:  black;
#             text-align:  center;
#             border-width:  thin;
#             border-style:  dotted;
#         }    #T_71ee24b2_f9f6_11ea_93be_acde48001122row0_col25 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#             border-color:  black;
